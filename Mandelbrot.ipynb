# %%
import Mandelbrot
side = 2
dens = 1000
center = (-0.5, 0)

checks = 200

x_members, y_members = Mandelbrot.find_members_parallel(side, center, dens, checks, 5)
Mandelbrot.plot_mandelbrot(side, center, x_members, y_members)
# Out:
# 100%|██████████| 1000/1000 [00:12<00:00, 80.70it/s]
